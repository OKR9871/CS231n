# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/cs231n/
# Out:
# /content/drive/MyDrive/cs231n

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/cs231n/.git/

# %%
# !remote add origin https://github.com/OKR9871/cs231n.git
# Out:
# /bin/bash: remote: command not found
